# %%
# Download the dataset

# !mkdir -p data/spam_data
# !ls data
# !wget https://spamassassin.apache.org/old/publiccorpus/20030228_easy_ham.tar.bz2
# !wget https://spamassassin.apache.org/old/publiccorpus/20030228_easy_ham_2.tar.bz2
# !wget https://spamassassin.apache.org/old/publiccorpus/20030228_spam.tar.bz2
# !wget https://spamassassin.apache.org/old/publiccorpus/20050311_spam_2.tar.bz2
# !wget https://spamassassin.apache.org/old/publiccorpus/20030228_hard_ham.tar.bz2
#
# !tar xvjf 20030228_easy_ham_2.tar.bz2
# !tar xvjf 20030228_easy_ham.tar.bz2
# !tar xvjf 20030228_hard_ham.tar.bz2
# !tar xvjf 20030228_spam.tar.bz2
# !tar xvjf 20050311_spam_2.tar.bz2
#
# !mv easy_ham data/spam_data
# !mv easy_ham_2 data/spam_data
# !mv hard_ham data/spam_data
# !mv spam data/spam_data
# !mv spam_2 data/spam_data

# %%
# Download the glove embedding
# !wget http://nlp.stanford.edu/data/glove.6B.zip
# !unzip glove.6B.zip
# !python -m gensim.scripts.glove2word2vec -i glove.6B.300d.txt -o glove.6B.300d.word2vec.txt

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')

# For file processing
import os
import glob
import email
import json
import csv

# For modeling
import random
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\59384\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\59384\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Define the file path

path = 'data/spam_data/'
easy_ham_paths = glob.glob(path+'easy_ham/*')
easy_ham_2_paths = glob.glob(path+'easy_ham_2/*')
hard_ham_paths = glob.glob(path+'hard_ham/*')
spam_paths = glob.glob(path+'spam/*')
spam_2_paths = glob.glob(path+'spam_2/*')

# %%
# Getting path for dataset
non_spam_path = easy_ham_paths + easy_ham_2_paths + hard_ham_paths
spam_path = spam_paths+spam_2_paths

print(f'Number of non-spam file: {len(non_spam_path)}')
print(f'Number of spam file: {len(spam_path)}')

# Expected:
# Number of non-spam file: 4153
# Number of spam file: 1898
# Out:
# Number of non-spam file: 4153
# Number of spam file: 1898

# %%
# Data Extraction:

non_spam_sentences = []
spam_sentences = []
non_spam_labels = []
spam_labels = []
count = 0

# Extract the body content for non-spam message
for path in non_spam_path:
    file = open(path, encoding="utf8", errors='ignore')
    try:
        msg = email.message_from_file(file)
        for part in msg.walk():
            if part.get_content_type() == 'text/plain':
                body = part.get_payload(decode=True).decode()
                non_spam_sentences.append(body)
                non_spam_labels.append(1)
                count+=1
    except Exception as e:
        print(e)
# Extract the body content for spam message
for path in spam_path:
    file = open(path, encoding="utf8", errors='ignore')
    try:
        msg = email.message_from_file(file)
        for part in msg.walk():
            if part.get_content_type() == 'text/plain':
                body = part.get_payload(decode=True).decode()
                spam_sentences.append(body)
                spam_labels.append(0)
                count+=1
    except Exception as e:
        print(e)

# Expect: the number of spam_sentences == number of spam_labels
print('\n')
print(f'number of spam_sentences: {len(spam_sentences)}')
print(f'number of spam_labels: {len(spam_labels)}')
print(f'number of non_spam_sentences: {len(non_spam_sentences)}')
print(f'number of non_spam_labels: {len(non_spam_labels)}')
# Inspect the message content
print(f"Non-Spam sample: \n{spam_sentences[0]}")
# Out:
# 'utf-8' codec can't decode byte 0xb4 in position 93: invalid start byte
# 'utf-8' codec can't decode byte 0xe8 in position 565: invalid continuation byte
# 'utf-8' codec can't decode byte 0xe9 in position 2073: invalid continuation byte
# 'utf-8' codec can't decode byte 0xe9 in position 1965: invalid continuation byte
# 'utf-8' codec can't decode byte 0xe9 in position 1456: invalid continuation byte
# 'utf-8' codec can't decode byte 0xe9 in position 1457: invalid continuation byte
# 'utf-8' codec can't decode byte 0xab in position 2130: invalid start byte
# 'utf-8' codec can't decode byte 0xb7 in position 1139: invalid start byte
# 'utf-8' codec can't decode byte 0xe9 in position 1652: invalid continuation byte
# 'utf-8' codec can't decode byte 0xab in position 1056: invalid start byte
# 'utf-8' codec can't decode byte 0xab in position 367: invalid start byte
# 'utf-8' codec can't decode byte 0xab in position 454: invalid start byte
# 'utf-8' codec can't decode byte 0xe9 in position 1452: invalid continuation byte
# 'utf-8' codec can't decode byte 0xa3 in position 529: invalid start byte
# 'utf-8' codec can't decode byte 0x80 in position 211: invalid start byte
# 'utf-8' codec can't decode byte 0xd8 in position 3221: invalid continuation byte
# 'utf-8' codec can't decode byte 0xa3 in position 1334: invalid start byte
# 'utf-8' codec can't decode byte 0x96 in position 1873: invalid start byte
# 'utf-8' codec can't decode byte 0xe1 in position 22: invalid continuation byte
# 'utf-8' codec can't decode byte 0x99 in position 562: invalid start byte
# 'utf-8' codec can't decode byte 0xee in position 1397: invalid continuation byte
# 'utf-8' codec can't decode byte 0x97 in position 353: invalid start byte
# 'utf-8' codec can't decode byte 0x92 in position 827: invalid start byte
# 'utf-8' codec can't decode byte 0x97 in position 861: invalid start byte
# 'utf-8' codec can't decode byte 0x85 in position 1991: invalid start byte
# 'utf-8' codec can't decode byte 0xae in position 1056: invalid start byte
# 'utf-8' codec can't decode byte 0x97 in position 441: invalid start byte
# 'utf-8' codec can't decode byte 0xb0 in position 81: invalid start byte
# 'utf-8' codec can't decode byte 0xe9 in position 1746: invalid continuation byte
# 'utf-8' codec can't decode byte 0xa7 in position 117: invalid start byte
# 'utf-8' codec can't decode byte 0x82 in position 59: invalid start byte
# 'utf-8' codec can't decode byte 0x97 in position 816: invalid start byte
# 'utf-8' codec can't decode byte 0x93 in position 7: invalid start byte
# 'utf-8' codec can't decode byte 0x97 in position 861: invalid start byte
# 'utf-8' codec can't decode byte 0xee in position 2231: invalid continuation byte
# 'utf-8' codec can't decode byte 0x82 in position 59: invalid start byte
# 'utf-8' codec can't decode byte 0x82 in position 59: invalid start byte
# 'utf-8' codec can't decode byte 0x82 in position 59: invalid start byte
# 'utf-8' codec can't decode byte 0x99 in position 586: invalid start byte
# 'utf-8' codec can't decode byte 0x92 in position 827: invalid start byte
# 'utf-8' codec can't decode byte 0xbc in position 580: invalid start byte
# 'utf-8' codec can't decode byte 0xff in position 2624: invalid start byte
# 'utf-8' codec can't decode byte 0xe9 in position 224: invalid continuation byte
# 'utf-8' codec can't decode byte 0xe7 in position 741: invalid continuation byte
# 'utf-8' codec can't decode byte 0xc6 in position 27: invalid continuation byte
# 'utf-8' codec can't decode byte 0xc6 in position 27: invalid continuation byte
# 'utf-8' codec can't decode byte 0xcb in position 21: invalid continuation byte
# 'utf-8' codec can't decode byte 0xe7 in position 741: invalid continuation byte
# 'utf-8' codec can't decode byte 0xe7 in position 741: invalid continuation byte
# 'utf-8' codec can't decode byte 0xc5 in position 105: invalid continuation byte
# 'utf-8' codec can't decode byte 0xb7 in position 130: invalid start byte
# 'utf-8' codec can't decode byte 0xf4 in position 1169: invalid continuation byte
# 'utf-8' codec can't decode byte 0xf4 in position 1169: invalid continuation byte
# 'utf-8' codec can't decode byte 0xa6 in position 229: invalid start byte
# 'utf-8' codec can't decode byte 0xa6 in position 229: invalid start byte
# 'utf-8' codec can't decode byte 0x99 in position 449: invalid start byte
# 'utf-8' codec can't decode byte 0xa1 in position 312: invalid start byte
# 'utf-8' codec can't decode byte 0xa0 in position 119: invalid start byte
# 'utf-8' codec can't decode byte 0xb1 in position 2092: invalid start byte
# 'utf-8' codec can't decode byte 0xfe in position 102: invalid start byte
# 'utf-8' codec can't decode byte 0xfe in position 102: invalid start byte
# 'utf-8' codec can't decode byte 0xa0 in position 42: invalid start byte
# 'utf-8' codec can't decode byte 0xbb in position 0: invalid start byte
# 'utf-8' codec can't decode byte 0x92 in position 177: invalid start byte
# 'utf-8' codec can't decode byte 0xe8 in position 826: invalid continuation byte
# 'utf-8' codec can't decode byte 0xe8 in position 826: invalid continuation byte
# 'utf-8' codec can't decode byte 0xdc in position 466: invalid continuation byte
# 'utf-8' codec can't decode byte 0x95 in position 271: invalid start byte
# 'utf-8' codec can't decode byte 0xae in position 363: invalid start byte
# 'utf-8' codec can't decode byte 0xdd in position 11: invalid continuation byte
# 'utf-8' codec can't decode byte 0xdd in position 0: invalid continuation byte
# 'utf-8' codec can't decode byte 0x96 in position 25: invalid start byte
# 'utf-8' codec can't decode byte 0xa0 in position 122: invalid start byte
# 'utf-8' codec can't decode byte 0xa0 in position 122: invalid start byte
# 'utf-8' codec can't decode byte 0xfc in position 8: invalid start byte
# 'utf-8' codec can't decode byte 0xfc in position 8: invalid start byte
# 'utf-8' codec can't decode byte 0x99 in position 130: invalid start byte
# 'utf-8' codec can't decode byte 0xe2 in position 416: invalid continuation byte
# 'utf-8' codec can't decode byte 0xb7 in position 620: invalid start byte
# 'utf-8' codec can't decode byte 0xb7 in position 531: invalid start byte
# 'utf-8' codec can't decode byte 0xa0 in position 10765: invalid start byte
# 'utf-8' codec can't decode byte 0x92 in position 700: invalid start byte
# 'utf-8' codec can't decode byte 0xa3 in position 260: invalid start byte
# 'utf-8' codec can't decode byte 0xa3 in position 260: invalid start byte
# 'utf-8' codec can't decode byte 0xa1 in position 295: invalid start byte
# 'utf-8' codec can't decode byte 0xb7 in position 15: invalid start byte
# 'utf-8' codec can't decode byte 0xb7 in position 15: invalid start byte
# 'utf-8' codec can't decode byte 0xb7 in position 15: invalid start byte
# 'utf-8' codec can't decode byte 0xb7 in position 15: invalid start byte
# 'utf-8' codec can't decode byte 0xae in position 1537: invalid start byte
# 'utf-8' codec can't decode byte 0xb1 in position 7: invalid start byte
# 'utf-8' codec can't decode byte 0xf1 in position 226: invalid continuation byte
# 'utf-8' codec can't decode byte 0x94 in position 927: invalid start byte
# 'utf-8' codec can't decode byte 0xf1 in position 278: invalid continuation byte
# 'utf-8' codec can't decode byte 0xae in position 1075: invalid start byte
# 'utf-8' codec can't decode byte 0xa1 in position 1075: invalid start byte
#
#
# number of spam_sentences: 970
# number of spam_labels: 970
# number of non_spam_sentences: 4035
# number of non_spam_labels: 4035
# Non-Spam sample:
# 1) Fight The Risk of Cancer!
# http://www.adclick.ws/p.cfm?o=315&s=pk007
#
# 2) Slim Down - Guaranteed to lose 10-12 lbs in 30 days
# http://www.adclick.ws/p.cfm?o=249&s=pk007
#
# 3) Get the Child Support You Deserve - Free Legal Advice
# http://www.adclick.ws/p.cfm?o=245&s=pk002
#
# 4) Join the Web's Fastest Growing Singles Community
# http://www.adclick.ws/p.cfm?o=259&s=pk007
#
# 5) Start Your Private Photo Album Online!
# http://www.adclick.ws/p.cfm?o=283&s=pk007
#
# Have a Wonderful Day,
# Offer Manager
# PrizeMama
#
#
#
#
#
#
#
#
#
#
#
#
#
# If you wish to leave this list please use the link below.
# http://www.qves.com/trim/?ilug@linux.ie%7C17%7C114258
#
#
# --
# Irish Linux Users' Group: ilug@linux.ie
# http://www.linux.ie/mailman/listinfo/ilug for (un)subscription information.
# List maintainer: listmaster@linux.ie

# %%
# Remove stopwords
import re
import string
from nltk.stem import WordNetLemmatizer
stopwords = [ "a", "about", "above", "after", "again", "against", "all", "am", "an", "and", "any", "are", "as", "at", "be", "because", "been", "before", "being", "below", "between", "both", "but", "by", "could", "did", "do", "does", "doing", "down", "during", "each", "few", "for", "from", "further", "had", "has", "have", "having", "he", "he'd", "he'll", "he's", "her", "here", "here's", "hers", "herself", "him", "himself", "his", "how", "how's", "i", "i'd", "i'll", "i'm", "i've", "if", "in", "into", "is", "it", "it's", "its", "itself", "let's", "me", "more", "most", "my", "myself", "nor", "of", "on", "once", "only", "or", "other", "ought", "our", "ours", "ourselves", "out", "over", "own", "same", "she", "she'd", "she'll", "she's", "should", "so", "some", "such", "than", "that", "that's", "the", "their", "theirs", "them", "themselves", "then", "there", "there's", "these", "they", "they'd", "they'll", "they're", "they've", "this", "those", "through", "to", "too", "under", "until", "up", "very", "was", "we", "we'd", "we'll", "we're", "we've", "were", "what", "what's", "when", "when's", "where", "where's", "which", "while", "who", "who's", "whom", "why", "why's", "with", "would", "you", "you'd", "you'll", "you're", "you've", "your", "yours", "yourself", "yourselves" ]

# %%
#----------------------Testing the cleaning operation on single sample--------------------
msg = spam_sentences[0]
# The upper and lower case should have no impact to the result(neg/pos), so we should convert all chars to lower case, to reduce the overhead of traning process.
msg.lower()
# Using regex to remove any not-chars or \', hyperlinks, emails addr, and same header information
pattern = '[^a-zA-Z\']|\_+|http\S+|\S*@\S*\s?|Date:.*|From:.*|Message.*'
replace = " "
msg = re.sub(pattern, replace, msg).strip()
# Calling re.sub again to remove those redundant whitespace
msg = re.sub('[\r\n\t ]+', replace, msg).strip()
# Remove the any word in stopwords from msg (Those words has no semantic meaning to our model, so we should remove them to reduce the training overhead)
msg = msg.split(' ')
msg = [word for word in msg if word not in stopwords]
msg = " ".join(msg)
msg
# Out:
# "Fight The Risk Cancer Slim Down Guaranteed lose lbs days Get Child Support You Deserve Free Legal Advice Join Web's Fastest Growing Singles Community Start Your Private Photo Album Online Have Wonderful Day Offer Manager PrizeMama If wish leave list please use link Irish Linux Users' Group un subscription information List maintainer"

# %%
#----------------------Applying the cleaning operation on all trainign data --------------------
def msg_cleaning(msg):
    # The upper and lower case should have no impact to the result(neg/pos), so we should convert all chars to lower case, to reduce the overhead of traning process.
    msg.lower()
    # Using regex to remove any not-chars or \', hyperlinks, emails addr, and same header information
    pattern = '[^a-zA-Z\']|\_+|http\S+|\S*@\S*\s?|Date:.*|From:.*|Message.*'
    replace = " "
    msg = re.sub(pattern, replace, msg).strip()
    # Calling re.sub again to remove those redundant whitespace
    msg = re.sub('[\r\n\t ]+', replace, msg).strip()
    # Remove the any word in stopwords from msg (Those words has no semantic meaning to our model, so we should remove them to reduce the training overhead)
    msg = msg.split(' ')
    msg = [word for word in msg if word not in stopwords]
    msg = " ".join(msg)
    return msg

# %%
# Process the data in the word-by-word fasion: Spcifically, for each word, if it's in the set of stopwords, remove it.
count = 0
for idx, msg in enumerate(spam_sentences):
    spam_sentences[idx] = msg_cleaning(msg)
for idx, msg in enumerate(non_spam_sentences):
    non_spam_sentences[idx] = msg_cleaning(msg)

print('\n')
print(f'number of spam_sentences: {len(spam_sentences)}')
print(f'number of spam_labels: {len(spam_labels)}')
print(f'number of non_spam_sentences: {len(non_spam_sentences)}')
print(f'number of non_spam_labels: {len(non_spam_labels)}')
# Now the msg looks much more clean, let's begin the Tokenization process.
# Out:
# number of spam_sentences: 970
# number of spam_labels: 970
# number of non_spam_sentences: 4035
# number of non_spam_labels: 4035

# %%
# Inspect the message content
# print(f"Non-Spam sample: \n{non_spam_sentences[0]}")
print(f"Spam sample: \n{spam_sentences[0]}")
# Out:
# Spam sample:
# Fight The Risk Cancer Slim Down Guaranteed lose lbs days Get Child Support You Deserve Free Legal Advice Join Web's Fastest Growing Singles Community Start Your Private Photo Album Online Have Wonderful Day Offer Manager PrizeMama If wish leave list please use link Irish Linux Users' Group un subscription information List maintainer

# %%
# Define the variables
vocab_size = 20000 # Size of word corpus
embedding_dim = 16 # dimension of output vector
max_length = 1000 # Maximum length of token
trunc_type = 'post'
padding_type = 'post'
oov_tok = '<ooV>'
training_portion = .7
testing_proportion = 0.1
train_size = 0

non_spam_train_size = int(len(non_spam_labels) * training_portion)
non_spam_test_size = int(len(non_spam_labels) * testing_proportion)
# Split the training, validation, and testing data based on the given proportion
x_train = non_spam_sentences[:non_spam_train_size]
y_train = non_spam_labels[:non_spam_train_size]
x_valid = non_spam_sentences[non_spam_train_size:-non_spam_test_size]
y_valid = non_spam_labels[non_spam_train_size:-non_spam_test_size]
x_test = non_spam_sentences[-non_spam_test_size:]
y_test = non_spam_labels[-non_spam_test_size:]
print("Expected the number of len(non_spam_labels) equals to the sum of len(train_labels)+len(valid_labels)")
print(f'Expected {len(y_train)}+{len(y_test)}=={len(non_spam_labels)}')

spam_train_size = int(len(spam_labels) * training_portion)
spam_test_size = int(len(spam_labels) * testing_proportion)
x_train += spam_sentences[:spam_train_size]
y_train += spam_labels[:spam_train_size]
x_valid += spam_sentences[spam_train_size:-spam_test_size]
y_valid += spam_labels[spam_train_size:-spam_test_size]
x_test += spam_sentences[-spam_test_size:]
y_test += spam_labels[-spam_test_size:]

train_size = len(x_train)+len(x_valid)

print('\n')
print(f'number of x_train: {len(x_train)}')
print(f'number of y_train: {len(y_train)}')
print(f'number of x_valid: {len(x_valid)}')
print(f'number of y_valid: {len(y_valid)}')
print(f'number of x_test: {len(x_test)}')
print(f'number of y_test: {len(y_test)}')
# Out:
# Expected the number of len(non_spam_labels) equals to the sum of len(train_labels)+len(valid_labels)
# Expected 2824+403==4035
#
#
# number of x_train: 3503
# number of y_train: 3503
# number of x_valid: 1002
# number of y_valid: 1002

# %%
# Inspect the message content
print(f"Non-Spam sample: \n{non_spam_sentences[0]}")
# print(f"Spam sample: \n{spam_sentences[0]}")
# Out:
# Non-Spam sample:
# I can't reproduce error For repeatable like every time without fail This debug log pick happening Pick It exec pick inbox list lbrace lbrace subject ftp rbrace rbrace sequence mercury exec pick inbox list lbrace lbrace subject ftp rbrace rbrace sequence mercury Ftoc PickMsgs hit Marking hits tkerror syntax error expression int Note I run pick command hand delta pick inbox list lbrace lbrace subject ftp rbrace rbrace sequence mercury hit That's hit comes obviously The version nmh I'm using delta pick version pick nmh compiled fuchsia cs mu OZ AU Sun Mar ICT And relevant part mh profile delta mhparam pick seq sel list Since pick command works sequence actually one explicit command line search popup one comes mh profile get created kre ps still using version code form day ago I haven't able reach cvs repository today local routing issue I think Exmh workers mailing list

# %%
## Process word by word
# def remove_null(datas,labels):
#     not_null_idx = [i for i,o in enumerate(datas) if o is not None]
#     return np.array(datas)[not_null_idx],np.array(labels)[not_null_idx]
# x_train,y_train = remove_null(x_train,y_train)
# x_test,y_test = remove_null(x_test,y_test)

print('\n')
print(f'number of x_train: {len(x_train)}')
print(f'number of y_train: {len(y_train)}')
print(f'number of x_valid: {len(x_valid)}')
print(f'number of y_valid: {len(y_valid)}')
print(f'number of x_test: {len(x_test)}')
print(f'number of y_test: {len(y_test)}')
# Out:
# number of x_train: 3503
# number of y_train: 3503
# number of x_valid: 1002
# number of y_valid: 1002
# number of x_test: 500
# number of y_test: 500

# %%
# Convert to numpy array
train_sentences, train_labels = np.array(x_train), np.array(y_train)
valid_sentences, valid_labels = np.array(x_valid), np.array(y_valid)
test_sentences, test_labels = np.array(x_test), np.array(y_test)

print(train_size)
print(len(train_sentences))
print(len(train_labels))
print(len(valid_sentences))
print(len(valid_labels))

# Expected output (if training_portion=.8)
# 4004
# 4004
# 4004
# 1001
# 1001
# Out:
# 4505
# 3503
# 3503
# 1002
# 1002

# %%
tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(train_sentences)
word_index = tokenizer.word_index

train_sequences = tokenizer.texts_to_sequences(train_sentences)
train_padded = pad_sequences(train_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

print("\nWord Index = " , word_index)
print(f"\nSequences[0]: {train_sentences[0]}")
print(f"Sequences[0]: {train_sequences[0]}")
print("Padded Sequences: ")
print(train_padded)
# Out:
# Word Index =  {'<ooV>': 1, 'i': 2, 'e': 3, 'b': 4, 'c': 5, 'f': 6, 'd': 7, 'not': 8, 'the': 9, 'br': 10, 'will': 11, 'mv': 12, 'can': 13, 'list': 14, 'a': 15, 'font': 16, 'one': 17, 'no': 18, 'just': 19, 'get': 20, 'this': 21, 'p': 22, 'email': 23, 'nbsp': 24, 'to': 25, 'you': 26, 'use': 27, 'people': 28, 'like': 29, 'time': 30, 'free': 31, 'now': 32, 'new': 33, 'mail': 34, 'if': 35, 'information': 36, "don't": 37, 'we': 38, 'make': 39, 'us': 40, 'it': 41, 'also': 42, 'wrote': 43, 'linux': 44, 'in': 45, 'mailing': 46, 'on': 47, 'td': 48, 'please': 49, 'work': 50, "i'm": 51, 'size': 52, 'want': 53, 'name': 54, 'first': 55, 'way': 56, 'and': 57, 'your': 58, 'said': 59, 'send': 60, 'money': 61, 'know': 62, 'even': 63, 'think': 64, 'see': 65, 'group': 66, 'color': 67, 'for': 68, 'message': 69, 'need': 70, 's': 71, 'using': 72, 'url': 73, 'much': 74, 'address': 75, 'many': 76, 'well': 77, "'": 78, 'line': 79, 'good': 80, 'may': 81, 'world': 82, 'business': 83, 'order': 84, 'internet': 85, 'rpm': 86, 'l': 87, 'cd': 88, 'spam': 89, 'ad': 90, 'right': 91, 'subject': 92, 'go': 93, 'find': 94, 'but': 95, 'de': 96, 'com': 97, 'home': 98, 'face': 99, 'take': 100, 'years': 101, 'net': 102, 'software': 103, 'irish': 104, 'best': 105, 'report': 106, 'file': 107, 'system': 108, 'x': 109, 'tr': 110, "i've": 111, 'day': 112, 'un': 113, 'every': 114, 'something': 115, 'help': 116, 'still': 117, 'subscription': 118, 'spamassassin': 119, 'back': 120, 'phone': 121, 'web': 122, 'used': 123, 'really': 124, 'check': 125, 'number': 126, 'exmh': 127, 'so': 128, 'two': 129, 'ac': 130, 'set': 131, 'receive': 132, 'change': 133, 'data': 134, 'within': 135, 'company': 136, 'html': 137, 'click': 138, 'maintainer': 139, 'long': 140, "users'": 141, 'sure': 142, 'say': 143, 'of': 144, 'site': 145, 'code': 146, 'problem': 147, 'cc': 148, 'pm': 149, 'old': 150, 'center': 151, 'without': 152, 'service': 153, 'all': 154, 'af': 155, 'since': 156, 'made': 157, 'run': 158, 'ff': 159, 'today': 160, 'year': 161, 'off': 162, 'better': 163, 'link': 164, 'perl': 165, 'r': 166, "it's": 167, 'life': 168, 'next': 169, 'width': 170, 'got': 171, 'last': 172, 'text': 173, 'states': 174, 'program': 175, 'must': 176, 'going': 177, 'type': 178, 't': 179, 'messages': 180, 'look': 181, 'anyone': 182, 'end': 183, 'never': 184, 'sent': 185, "doesn't": 186, 'another': 187, 'read': 188, 'razor': 189, 'as': 190, 'u': 191, 'they': 192, 'might': 193, "can't": 194, 'million': 195, 'there': 196, 'call': 197, 'aa': 198, 'found': 199, 'do': 200, 'try': 201, 'remove': 202, 'is': 203, 'my': 204, 'give': 205, 'files': 206, 'ec': 207, 'align': 208, 'form': 209, 'times': 210, 'ca': 211, 'state': 212, 'case': 213, 'real': 214, 'per': 215, 'credit': 216, 'ab': 217, 'arial': 218, 'different': 219, 'users': 220, 'ce': 221, 'bb': 222, 'href': 223, 'things': 224, 'thanks': 225, 'db': 226, 'package': 227, 'what': 228, 'thing': 229, 'days': 230, 'etc': 231, 'computer': 232, 'easy': 233, 'bf': 234, 'm': 235, 'bc': 236, 'security': 237, 'available': 238, 'original': 239, 'card': 240, 'great': 241, 'that': 242, 'come': 243, 'fb': 244, 'ea': 245, 'looking': 246, 'kernel': 247, 'n': 248, 'yes': 249, 'ba': 250, 'start': 251, 'actually': 252, 'top': 253, 'less': 254, 'ee': 255, 'united': 256, 'ed': 257, 'product': 258, 'build': 259, 'support': 260, 'put': 261, 'server': 262, 'cb': 263, 'removed': 264, 'point': 265, 'keep': 266, 'sep': 267, 'high': 268, 'working': 269, 'place': 270, 'government': 271, 'eb': 272, 'offer': 273, 'based': 274, 'companies': 275, 'k': 276, 'ever': 277, 'version': 278, 'probably': 279, 'though': 280, 'anything': 281, 'fd': 282, 'ae': 283, 'network': 284, 'da': 285, 'fa': 286, 'cf': 287, 'user': 288, 'someone': 289, 'part': 290, 'dc': 291, 'ef': 292, 'fc': 293, 'received': 294, 'following': 295, 'marketing': 296, 'running': 297, 'however': 298, 'course': 299, 'df': 300, 'with': 301, 'w': 302, 'access': 303, 'around': 304, 'mr': 305, "didn't": 306, 'addresses': 307, 'online': 308, 'page': 3 ...
#
# Sequences[0]: I can't reproduce error For repeatable like every time without fail This debug log pick happening Pick It exec pick inbox list lbrace lbrace subject ftp rbrace rbrace sequence mercury exec pick inbox list lbrace lbrace subject ftp rbrace rbrace sequence mercury Ftoc PickMsgs hit Marking hits tkerror syntax error expression int Note I run pick command hand delta pick inbox list lbrace lbrace subject ftp rbrace rbrace sequence mercury hit That's hit comes obviously The version nmh I'm using delta pick version pick nmh compiled fuchsia cs mu OZ AU Sun Mar ICT And relevant part mh profile delta mhparam pick seq sel list Since pick command works sequence actually one explicit command line search popup one comes mh profile get created kre ps still using version code form day ago I haven't able reach cvs repository today local routing issue I think Exmh workers mailing list
# Sequences[0]: [2, 194, 5295, 356, 68, 1, 29, 114, 30, 152, 2132, 21, 1416, 433, 630, 3696, 630, 41, 3339, 630, 1517, 14, 7201, 7201, 92, 1019, 7202, 7202, 782, 5908, 3339, 630, 1517, 14, 7201, 7201, 92, 1019, 7202, 7202, 782, 5908, 1053, 6709, 584, 8573, 2429, 1, 2430, 356, 2879, 1235, 474, 2, 158, 630, 908, 703, 3969, 630, 1517, 14, 7201, 7201, 92, 1019, 7202, 7202, 782, 5908, 584, 434, 584, 825, 1365, 9, 278, 2807, 51, 72, 3969, 630, 278, 630, 2807, 1742, 1, 7848, 15504, 1160, 2948, 745, 4368, 1, 57, 1824, 290, 1197, 3208, 3969, 1, 630, 2721, 2949, 14, 156, 630, 908, 329, 782, 252, 17, 5556, 908, 79, 477, 7203, 17, 825, 1197, 3208, 20, 1283, 3023, 2216, 117, 72, 278, 146, 209, 112, 497, 2, 793, 362, 711, 667, 1961, 160, 380, 4166, 437, 2, 64, 127, 1045, 46, 14]
# Padded Sequences:
# [[   2  194 5295 ...    0    0    0]
#  [2661   15  773 ...    0    0    0]
#  [ 542 8574 8575 ...    0    0    0]
#  ...
#  [1960 1028 2509 ...    0    0    0]
#  [ 514   51 1271 ...  240   49  715]
#  [ 109  137  137 ...    0    0    0]]

# %%
valid_sequences = tokenizer.texts_to_sequences(valid_sentences)
valid_padded = pad_sequences(valid_sequences, maxlen=max_length, truncating=trunc_type)
print(f"\nSequences[0]: {valid_sentences[0]}")
print(f"Sequences[0]: {valid_sequences[0]}")
print("Padded Sequences: ")
print(valid_padded)
# Out:
# Sequences[0]: Is way mailing list can turned newsgroup Newsgroups great threading discussions working offline I feel work much better sort technical discussion mailing list I suppose personal preference I disagree strongly Irish Linux Users' Group un subscription information List maintainer
# Sequences[0]: [203, 56, 46, 14, 13, 1518, 6671, 3197, 241, 11292, 4916, 269, 5170, 2, 641, 50, 74, 163, 777, 1068, 1912, 46, 14, 2, 1880, 447, 4474, 2, 3228, 2208, 104, 44, 141, 66, 113, 118, 36, 14, 139]
# Padded Sequences:
# [[    0     0     0 ...    36    14   139]
#  [    0     0     0 ...    36    14   139]
#  [    0     0     0 ...    36    14   139]
#  ...
#  [    0     0     0 ...    14   138 15487]
#  [    0     0     0 ...   372    93    87]
#  [    0     0     0 ...   138   138   202]]

# %%
test_sequences = tokenizer.texts_to_sequences(test_sentences)
test_padded = pad_sequences(valid_sequences, maxlen=max_length, truncating=trunc_type)
print(f"\nSequences[0]: {test_sentences[0]}")
print(f"Sequences[0]: {test_sequences[0]}")
print("Padded Sequences: ")
print(test_padded)
# Out:
# Sequences[0]: branching thread I found another Ximian repository I don't know works yet rpm redhat deps rpm src redhat deps rpm redhat deps ximian rpm src redhat deps ximian rpm redhat deps gnomehide rpm src redhat deps gnomehide These guys EXTREMELY apt friendly Unlike multimedia projects seem prefer RPM Apt older methods Isn't cool Hey I known apt get install gnome session kick off Brian Fahrlnder Linux Zealot Conservative Technomad Evansville IN My Voyage ICQ I don't want hear news Isreal news contains words Bullet Brain Arafat RPM List mailing list
# Sequences[0]: [1, 3726, 2, 199, 187, 1033, 1961, 2, 37, 62, 329, 428, 86, 435, 1, 86, 814, 435, 1, 86, 435, 1, 1033, 86, 814, 435, 1, 1033, 86, 435, 1, 9285, 86, 814, 435, 1, 9285, 603, 1172, 1662, 384, 2677, 2767, 8629, 1881, 490, 1475, 86, 384, 3176, 1541, 441, 1466, 1965, 2, 732, 384, 20, 415, 1269, 4400, 4174, 162, 1844, 7435, 44, 6465, 2195, 7436, 7437, 45, 204, 7438, 2785, 2, 37, 53, 1169, 313, 1, 313, 805, 638, 4926, 1951, 1, 86, 14, 46, 14]
# Padded Sequences:
# [[    0     0     0 ...    36    14   139]
#  [    0     0     0 ...    36    14   139]
#  [    0     0     0 ...    36    14   139]
#  ...
#  [    0     0     0 ...    14   138 15487]
#  [    0     0     0 ...   372    93    87]
#  [    0     0     0 ...   138   138   202]]

# %%
# Convering the label to numpy array
training_labels_final = np.array(train_labels)
valid_labels_final = np.array(valid_labels)
testing_labels_final = np.array(test_labels)
print('\n')
print(f'number of x_train: {len(train_padded)}')
print(f'number of y_train: {len(training_labels_final)}')
print(f'number of x_valid: {len(valid_padded)}')
print(f'number of y_valid: {len(valid_labels_final)}')
print(f'number of x_test: {len(test_labels)}')
print(f'number of y_test: {len(testing_labels_final)}')
# Out:
# number of x_train: 3503
# number of y_train: 3503
# number of x_valid: 1002
# number of y_valid: 1002
# number of x_test: 500
# number of y_test: 500

# %%
#-----------------Baseline model----------------

model = tf.keras.models.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.GRU(64, return_sequences=True)),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True)),
    tf.keras.layers.GlobalMaxPool1D(),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.summary()
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 1000, 16)          320000
# _________________________________________________________________
# bidirectional_4 (Bidirection (None, 1000, 128)         31488
# _________________________________________________________________
# bidirectional_5 (Bidirection (None, 1000, 128)         98816
# _________________________________________________________________
# global_max_pooling1d_2 (Glob (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                2064
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 452,385
# Trainable params: 452,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('acc')>0.999):
            print("\nThe accuracy reach 99.9%, and the process is about to stop")
            self.model.stop_training = True
callbacks = myCallback()
# Training the models
history = model.fit(
    train_padded,
    training_labels_final,
    batch_size=512,
    epochs=50,
    validation_data=(valid_padded, valid_labels_final),
    callbacks=[callbacks]
)
model.save("spam_filter_v3.h5")
# Out:
# Train on 3503 samples, validate on 1002 samples
# Epoch 1/50
# 3503/3503 [==============================] - 12s 3ms/sample - loss: 0.6559 - acc: 0.7245 - val_loss: 0.5849 - val_acc: 0.8064
# Epoch 2/50
# 3503/3503 [==============================] - 3s 833us/sample - loss: 0.5331 - acc: 0.8062 - val_loss: 0.5096 - val_acc: 0.8064
# Epoch 3/50
# 3503/3503 [==============================] - 3s 840us/sample - loss: 0.5077 - acc: 0.8062 - val_loss: 0.4935 - val_acc: 0.8064
# Epoch 4/50
# 3503/3503 [==============================] - 3s 832us/sample - loss: 0.4973 - acc: 0.8062 - val_loss: 0.4895 - val_acc: 0.8064
# Epoch 5/50
# 3503/3503 [==============================] - 3s 836us/sample - loss: 0.4880 - acc: 0.8062 - val_loss: 0.4876 - val_acc: 0.8064
# Epoch 6/50
# 3503/3503 [==============================] - 3s 878us/sample - loss: 0.4836 - acc: 0.8062 - val_loss: 0.4854 - val_acc: 0.8064
# Epoch 7/50
# 3503/3503 [==============================] - 3s 836us/sample - loss: 0.4793 - acc: 0.8062 - val_loss: 0.4783 - val_acc: 0.8064
# Epoch 8/50
# 3503/3503 [==============================] - 3s 849us/sample - loss: 0.4533 - acc: 0.8065 - val_loss: 0.4417 - val_acc: 0.8094
# Epoch 9/50
# 3503/3503 [==============================] - 3s 846us/sample - loss: 0.3396 - acc: 0.8341 - val_loss: 0.2614 - val_acc: 0.8523
# Epoch 10/50
# 3503/3503 [==============================] - 3s 862us/sample - loss: 0.1288 - acc: 0.9794 - val_loss: 0.1415 - val_acc: 0.9661
# Epoch 11/50
# 3503/3503 [==============================] - 3s 879us/sample - loss: 0.0524 - acc: 0.9892 - val_loss: 0.1294 - val_acc: 0.9661
# Epoch 12/50
# 3503/3503 [==============================] - 3s 847us/sample - loss: 0.0340 - acc: 0.9937 - val_loss: 0.1994 - val_acc: 0.9621
# Epoch 13/50
# 3072/3503 [=========================>....] - ETA: 0s - loss: 0.0252 - acc: 0.9958
# The accuracy reach 99.9%, and the process is about to stop
# 3503/3503 [==============================] - 3s 838us/sample - loss: 0.0232 - acc: 0.9960 - val_loss: 0.1308 - val_acc: 0.9611

# %%
import matplotlib.pyplot as plt

def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

plot_graphs(history, "acc")
plot_graphs(history, "loss")

# %%
test = test_padded[1]
x = np.expand_dims(test, axis=1)
x.shape
# Out:
# (1000, 1)

# %%
# Making Predictions
import numpy as np
import keras
# from keras.preprocessing import image
root_dir = "./test_data"
# Process file path
file_names = os.listdir(root_dir)
for idx, test in enumerate(test_padded):
    # Making prediction
    x = np.expand_dims(test, axis=0)
    classes = model.predict(x)
    print(f"Label is : {valid_labels_final[idx]}")
    if classes[0]>0.5:
      print("Result is a spam")
    else:
      print("Result is a non_spam")
# Out:
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a non_spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a non_spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a non_spam
# Label is : 1
# Result is a non_spam
# Label is : 1
# Result is a non_spam
# Label is : 1
# Result is a non_spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a non_spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a non_spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a non_spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a non_spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a non_spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a non_spam
# Label is : 1
# Result is a non_spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a non_spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a non_spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a non_spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a non_spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a non_spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a non_spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a non_spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a non_spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a non_spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a non_spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a non_spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a non_spam
# Label is : 1
# Result is a non_spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 1
# Result is a spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a spam
# Label is : 0
# Result is a spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam
# Label is : 0
# Result is a non_spam

# %%
model.layers
# Out:
# [<tensorflow.python.keras.layers.embeddings.Embedding at 0x23fa7eefc48>,
#  <tensorflow.python.keras.layers.wrappers.Bidirectional at 0x23f9fe66a08>,
#  <tensorflow.python.keras.layers.wrappers.Bidirectional at 0x23f9e282fc8>,
#  <tensorflow.python.keras.layers.pooling.GlobalMaxPooling1D at 0x23f9e3fedc8>,
#  <tensorflow.python.keras.layers.core.Dense at 0x23fac56ae48>,
#  <tensorflow.python.keras.layers.core.Dropout at 0x23fa7f38448>,
#  <tensorflow.python.keras.layers.core.Dense at 0x23fac682988>]

# %%
# Display in TensorFlow Embedding Projector:

# Extract the embedding layer's weight
e = model.layers[0]
weights = e.get_weights()[0]
print(f'Inspecting Embedding layer\'s shape: {weights.shape}')

# To reverse key-value pair in word_index for plotting
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
def decode_review(text):
    # Concatenate any number of strings
    return ' '.join([reverse_word_index.get(i, '?') for i in text])
    # print([reverse_word_index.get(i, '?') for i in text])
    # return x
print(f"Original text: {train_sentences[1]}")
print(f"Decoded text: {decode_review(train_padded[1])}")

# Save the vectors and their metadata into files
import io
out_v = io.open('imdb_vecs.tsv', 'w', encoding='utf-8')
out_m = io.open('imdb_meta.tsv', 'w', encoding='utf-8')
for word_num in range(1, vocab_size):
  word = reverse_word_index[word_num]
  embeddings = weights[word_num]
  out_m.write(word + "\n")
  out_v.write('\t'.join([str(x) for x in embeddings]) + "\n")
out_v.close()
out_m.close()

# Note: The TensorFlow Projector reads this file type and uses it to plot the vectors in 3D space so we can visualize them.
# Out:
# Inspecting Embedding layer's shape: (20000, 16)
# Original text: Martin A posted Tassos Papadopoulos Greek sculptor behind plan judged limestone Mount Kerdylio miles east Salonika not far Mount Athos monastic community ideal patriotic sculpture As well Alexander's granite features ft high ft wide museum restored amphitheatre car park admiring crowds planned So mountain limestone granite If limestone it'll weather pretty fast Yahoo Groups Sponsor DVDs Free s p Join Now To unsubscribe group send email Your use Yahoo Groups subject
# Decoded text: martin a posted <ooV> <ooV> greek sculptor behind plan judged limestone mount <ooV> miles east <ooV> not far mount <ooV> <ooV> community ideal <ooV> sculpture as well <ooV> granite features ft high ft wide museum restored <ooV> car park <ooV> crowds planned so mountain limestone granite if limestone it'll weather pretty fast yahoo groups sponsor dvds free s p join now to unsubscribe group send email your use yahoo groups subject ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?

# %% [markdown]
# #---------------- Model v2: with pretrained model----------------

# %%
from nltk.tokenize import word_tokenize

# Play around with Word2vector
# Out:
# c:\users\59384\anaconda3\envs\facecourse-py3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.feature_extraction.stop_words module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_extraction.text. Anything that cannot be imported from sklearn.feature_extraction.text is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
from gensim.models import KeyedVectors

w2v = KeyedVectors.load_word2vec_format('glove.6B.300d.word2vec.txt',binary=False)

# %%
## Use Glove Pretrain
import matplotlib.pyplot as plt
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, Input, LSTM, Embedding, Dropout, Activation, CuDNNGRU, Conv1D
from keras.layers import Bidirectional, GlobalMaxPool1D
from keras.models import Model
from keras import initializers, regularizers, constraints, optimizers, layers

# %%
maxlen = 2000
max_features = 50000

# %%
EMBEDDING_FILE = 'glove.6B.300d.txt'
tokenizer = Tokenizer(num_words=max_features)

# %%
tokenizer.fit_on_texts(x_train)

# %%
x_train_features = np.array(tokenizer.texts_to_sequences(x_train))
x_test_features = np.array(tokenizer.texts_to_sequences(x_test))

x_train_features = pad_sequences(x_train_features,maxlen=maxlen)
x_test_features = pad_sequences(x_test_features,maxlen=maxlen)

# %%
def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')
embeddings_index = dict(get_coefs(*o.split(" ")) for o in open(EMBEDDING_FILE))

all_embs = np.stack(embeddings_index.values())
emb_mean,emb_std = all_embs.mean(), all_embs.std()
embed_size = all_embs.shape[1]
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-54-2ed193a86bd2> in <module>
#       1 def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')
# ----> 2 embeddings_index = dict(get_coefs(*o.split(" ")) for o in open(EMBEDDING_FILE))
#       3
#       4 all_embs = np.stack(embeddings_index.values())
#       5 emb_mean,emb_std = all_embs.mean(), all_embs.std()
#
# <ipython-input-54-2ed193a86bd2> in <genexpr>(.0)
#       1 def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')
# ----> 2 embeddings_index = dict(get_coefs(*o.split(" ")) for o in open(EMBEDDING_FILE))
#       3
#       4 all_embs = np.stack(embeddings_index.values())
#       5 emb_mean,emb_std = all_embs.mean(), all_embs.std()
#
# c:\users\59384\anaconda3\envs\facecourse-py3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 6148: character maps to <undefined>

# %%
word_index = tokenizer.word_index
nb_words = min(max_features, len(word_index))
embedding_matrix = np.random.normal(emb_mean, emb_std, (nb_words, embed_size))
for word, i in word_index.items():
    if i >= max_features: continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None: embedding_matrix[i] = embedding_vector
        
inp = Input(shape=(maxlen,))
x = Embedding(max_features, embed_size, weights=[embedding_matrix])(inp)
x = Bidirectional(CuDNNGRU(64, return_sequences=True))(x)
x = GlobalMaxPool1D()(x)
x = Dense(16, activation="relu")(x)
x = Dropout(0.1)(x)
x = Dense(1, activation="sigmoid")(x)
model = Model(inputs=inp, outputs=x)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())

# %%
model.layers[1].trainable = False

# %%
history = model.fit(x_train_features,y_train, batch_size=512, epochs=20, 
          validation_data=(x_test_features, y_test))

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Neural Network w Embedding From Scratch

# %%
# Neural Network w Embedding From Scratch

# %%
## some config values 
embed_size = 100 # how big is each word vector
max_feature = 50000 # how many unique words to use (i.e num rows in embedding vector)
max_len = 2000 # max number of words in a question to use

# %%
tokenizer = Tokenizer(num_words=max_feature)

# %%
tokenizer.fit_on_texts(x_train)

# %%
x_train_features = np.array(tokenizer.texts_to_sequences(x_train))
x_test_features = np.array(tokenizer.texts_to_sequences(x_test))

# %% [markdown]
# x_train_features = pad_sequences(x_train_features,maxlen=max_len)
# x_test_features = pad_sequences(x_test_features,maxlen=max_len)

# %%
embed_size = 100

inp = Input(shape=(max_len,))
x = Embedding(max_feature, embed_size)(inp)
x = Bidirectional(CuDNNGRU(64, return_sequences=True))(x)
x = GlobalMaxPool1D()(x)
x = Dense(16, activation="relu")(x)
x = Dropout(0.1)(x)
x = Dense(1, activation="sigmoid")(x)
model = Model(inputs=inp, outputs=x)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

print(model.summary())

# %% [markdown]
# history = model.fit(x_train_features, y_train, batch_size=512, epochs=20, validation_data=(x_test_features, y_test))

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
## Neural Network
